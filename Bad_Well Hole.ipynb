# %%
# -*- coding: utf-8 -*-
from __future__ import division
from math import *
from TechlogMath import *
from operator import *
import sys
if sys.version_info[0]==3:
    from six.moves import range

PI     = 3.14159265358979323846
PIO2   = 1.57079632679489661923
PIO4   = 7.85398163397448309616E-1
SQRT2  = 1.41421356237309504880
SQRTH  = 7.07106781186547524401E-1
E      = exp(1)
LN2    = log(2)
LN10   = log(10)
LOG2E  = 1.4426950408889634073599
LOG10E = 1.0 / LN10
MissingValue = -9999
def iif(condition, trueResult=MissingValue, falseResult=MissingValue):
	if condition:
		return trueResult
	else:
		return falseResult

#Declarations
#The dictionary of parameters v2.0
#name,bname,type,family,measurement,unit,value,mode,description,group,min,max,list,enable,iscombocheckbox,isused
parameterDict = {}
try:
	if Parameter:
		pass
except NameError:
	class Parameter:
		def __init__(self, **d):
			pass
#Type:Variable Optional
#BName:bs
#Family:Bit Size
#Unit:in
#Mode:In
#Description:Description
BS = Variable("42003407260000", "LQC", "BS", u"Bit Size", u"in")
parameterDict.update({'BS' : Parameter(name='BS',bname='bs',type='Variable Optional',family='Bit Size',measurement='',unit='in',value='42003407260000.LQC.BS',mode='In',description='Description',group='',min='',max='',list='',enable='True',iscombocheckbox='False',isused='True')})
#Type:Variable Optional
#BName:cali
#Family:Caliper
#Unit:in
#Mode:In
#Description:Description
CALI = Variable("42003407260000", "LQC", "CALI", u"Caliper", u"in")
parameterDict.update({'CALI' : Parameter(name='CALI',bname='cali',type='Variable Optional',family='Caliper',measurement='',unit='in',value='42003407260000.LQC.CALI',mode='In',description='Description',group='',min='',max='',list='',enable='True',iscombocheckbox='False',isused='True')})
#Type:Variable Optional
#BName:rhob
#Family:Bulk Density
#Unit:G/C3
#Mode:In
#Description:Description
RHOB = Variable("42003407260000", "LQC", "RHOB", u"Bulk Density", u"G/C3")
parameterDict.update({'RHOB' : Parameter(name='RHOB',bname='rhob',type='Variable Optional',family='Bulk Density',measurement='',unit='G/C3',value='42003407260000.LQC.RHOB',mode='In',description='Description',group='',min='',max='',list='',enable='True',iscombocheckbox='False',isused='True')})
#Type:Variable Optional
#BName:drho
#Family:Bulk Density Correction
#Unit:G/C3
#Mode:In
#Description:Description
DRHO = Variable("42003407260000", "LQC", "DRHO", u"Bulk Density Correction", u"G/C3")
parameterDict.update({'DRHO' : Parameter(name='DRHO',bname='drho',type='Variable Optional',family='Bulk Density Correction',measurement='',unit='G/C3',value='42003407260000.LQC.DRHO',mode='In',description='Description',group='',min='',max='',list='',enable='True',iscombocheckbox='False',isused='True')})
#Type:Variable
#BName:flag
#Family:General Flag
#Unit:unitless
#Mode:Out
#Description:Description
#Format:auto
FLAG = Variable("42003407260000", "LQC", "FLAG", u"General Flag", u"unitless")
parameterDict.update({'FLAG' : Parameter(name='FLAG',bname='flag',type='Variable',family='General Flag',measurement='',unit='unitless',value='42003407260000.LQC.FLAG',mode='Out',description='Description',group='',min='',max='',list='',enable='True',iscombocheckbox='False',isused='True')})
#Type:Variable Optional
#BName:nphi
#Family:Neutron Porosity
#Unit:v/v
#Mode:In
#Description:Description
NPHI = Variable("42003407260000", "LQC", "NPHI", u"Neutron Porosity", u"v/v")
parameterDict.update({'NPHI' : Parameter(name='NPHI',bname='nphi',type='Variable Optional',family='Neutron Porosity',measurement='',unit='v/v',value='42003407260000.LQC.NPHI',mode='In',description='Description',group='',min='',max='',list='',enable='True',iscombocheckbox='False',isused='True')})
#Type:Variable Optional
#BName:pef
#Family:Photoelectric Factor
#Unit:b/e
#Mode:In
#Description:Description
PEF = Variable("42003407260000", "LQC", "PEF", u"Photoelectric Factor", u"b/e")
parameterDict.update({'PEF' : Parameter(name='PEF',bname='pef',type='Variable Optional',family='Photoelectric Factor',measurement='',unit='b/e',value='42003407260000.LQC.PEF',mode='In',description='Description',group='',min='',max='',list='',enable='True',iscombocheckbox='False',isused='True')})
#Type:Variable
#BName:dcal
#Family:Differential Caliper
#Unit:in
#Mode:Out
#Description:Description
#Format:auto
DCAL = Variable("42003407260000", "LQC", "DCAL", u"Differential Caliper", u"in")
parameterDict.update({'DCAL' : Parameter(name='DCAL',bname='dcal',type='Variable',family='Differential Caliper',measurement='',unit='in',value='42003407260000.LQC.DCAL',mode='Out',description='Description',group='',min='',max='',list='',enable='True',iscombocheckbox='False',isused='True')})
#Type:Variable
#BName:nphi_clean
#Family:Thermal Neutron Porosity
#Unit:ft3/ft3
#Mode:Out
#Description:Description
#Format:auto
NPHI_CLEAN = Variable("42003407260000", "LQC", "NPHI_CLEAN", u"Thermal Neutron Porosity", u"ft3/ft3")
parameterDict.update({'NPHI_CLEAN' : Parameter(name='NPHI_CLEAN',bname='nphi_clean',type='Variable',family='Thermal Neutron Porosity',measurement='',unit='ft3/ft3',value='42003407260000.LQC.NPHI_CLEAN',mode='Out',description='Description',group='',min='',max='',list='',enable='True',iscombocheckbox='False',isused='True')})
#Type:Variable
#BName:pef_clean
#Family:Photoelectric Factor
#Unit:b/e
#Mode:Out
#Description:Description
#Format:auto
PEF_CLEAN = Variable("42003407260000", "LQC", "PEF_CLEAN", u"Photoelectric Factor", u"b/e")
parameterDict.update({'PEF_CLEAN' : Parameter(name='PEF_CLEAN',bname='pef_clean',type='Variable',family='Photoelectric Factor',measurement='',unit='b/e',value='42003407260000.LQC.PEF_CLEAN',mode='Out',description='Description',group='',min='',max='',list='',enable='True',iscombocheckbox='False',isused='True')})
#Type:Variable
#BName:rhob_clean
#Family:Bulk Density
#Unit:g/cm3
#Mode:Out
#Description:Description
#Format:auto
RHOB_CLEAN = Variable("42003407260000", "LQC", "RHOB_CLEAN", u"Bulk Density", u"g/cm3")
parameterDict.update({'RHOB_CLEAN' : Parameter(name='RHOB_CLEAN',bname='rhob_clean',type='Variable',family='Bulk Density',measurement='',unit='g/cm3',value='42003407260000.LQC.RHOB_CLEAN',mode='Out',description='Description',group='',min='',max='',list='',enable='True',iscombocheckbox='False',isused='True')})
#Type:Variable
#BName:badhole
#Family:General Flag
#Unit:unitless
#Mode:Out
#Description:Description
#Format:auto
BADHOLE = Variable("42003407260000", "LQC", "BADHOLE", u"General Flag", u"unitless")
parameterDict.update({'BADHOLE' : Parameter(name='BADHOLE',bname='badhole',type='Variable',family='General Flag',measurement='',unit='unitless',value='42003407260000.LQC.BADHOLE',mode='Out',description='Description',group='',min='',max='',list='',enable='True',iscombocheckbox='False',isused='True')})
#Type:Variable Optional
#BName:ress
#Family:Resistivity - Shallow Laterolog
#Unit:OHMM
#Mode:In
#Description:Description
RESS = Variable("42003407260000", "LQC", "RESS", u"Resistivity - Shallow Laterolog", u"OHMM")
parameterDict.update({'RESS' : Parameter(name='RESS',bname='ress',type='Variable Optional',family='Resistivity - Shallow Laterolog',measurement='',unit='OHMM',value='42003407260000.LQC.RESS',mode='In',description='Description',group='',min='',max='',list='',enable='True',iscombocheckbox='False',isused='True')})
#Type:Variable Optional
#BName:resd
#Family:Resistivity - Deep Laterolog
#Unit:OHMM
#Mode:In
#Description:Description
RESD = Variable("42003407260000", "LQC", "RESD", u"Resistivity - Deep Laterolog", u"OHMM")
parameterDict.update({'RESD' : Parameter(name='RESD',bname='resd',type='Variable Optional',family='Resistivity - Deep Laterolog',measurement='',unit='OHMM',value='42003407260000.LQC.RESD',mode='In',description='Description',group='',min='',max='',list='',enable='True',iscombocheckbox='False',isused='True')})
#Type:Variable Optional
#BName:ecgr
#Family:Gamma Ray
#Unit:API
#Mode:In
#Description:Description
ECGR_REF = Variable("42003407260000", "LQC", "ECGR_REF", u"Gamma Ray", u"API")
parameterDict.update({'ECGR_REF' : Parameter(name='ECGR_REF',bname='ecgr',type='Variable Optional',family='Gamma Ray',measurement='',unit='API',value='42003407260000.LQC.ECGR_REF',mode='In',description='Description',group='',min='',max='',list='',enable='True',iscombocheckbox='False',isused='True')})
#Type:Variable
#BName:ecgr_clean
#Family:Gamma Ray
#Unit:gAPI
#Mode:Out
#Description:Description
#Format:auto
ECGR_CLEAN = Variable("42003407260000", "LQC", "ECGR_CLEAN", u"Gamma Ray", u"gAPI")
parameterDict.update({'ECGR_CLEAN' : Parameter(name='ECGR_CLEAN',bname='ecgr_clean',type='Variable',family='Gamma Ray',measurement='',unit='gAPI',value='42003407260000.LQC.ECGR_CLEAN',mode='Out',description='Description',group='',min='',max='',list='',enable='True',iscombocheckbox='False',isused='True')})
#Type:Variable
#BName:resd_clean
#Family:Resistivity - Deep
#Unit:ohm.m
#Mode:Out
#Description:Description
#Format:auto
RESD_CLEAN = Variable("42003407260000", "LQC", "RESD_CLEAN", u"Resistivity - Deep", u"ohm.m")
parameterDict.update({'RESD_CLEAN' : Parameter(name='RESD_CLEAN',bname='resd_clean',type='Variable',family='Resistivity - Deep',measurement='',unit='ohm.m',value='42003407260000.LQC.RESD_CLEAN',mode='Out',description='Description',group='',min='',max='',list='',enable='True',iscombocheckbox='False',isused='True')})
#Type:Variable
#BName:ress_clean
#Family:Resistivity - Shallow
#Unit:ohm.m
#Mode:Out
#Description:Description
#Format:auto
RESS_CLEAN = Variable("42003407260000", "LQC", "RESS_CLEAN", u"Resistivity - Shallow", u"ohm.m")
parameterDict.update({'RESS_CLEAN' : Parameter(name='RESS_CLEAN',bname='ress_clean',type='Variable',family='Resistivity - Shallow',measurement='',unit='ohm.m',value='42003407260000.LQC.RESS_CLEAN',mode='Out',description='Description',group='',min='',max='',list='',enable='True',iscombocheckbox='False',isused='True')})

__author__ = """Aaquib Hussain, Jitesh Vij"""
__date__ = """2019-07-31"""
__version__ = """1.0"""
__pyVersion__ = """2"""
__group__ = """"""
__suffix__ = """"""
__prefix__ = """"""
__applyMode__ = """0"""
__awiEngine__ = """v1"""
__layoutTemplateMode__ = """"""
__includeMissingValues__ = """True"""
__keepPreviouslyComputedValues__ = """True"""
__areInputDisplayed__ = """True"""
__useMultiWellLayout__ = """True"""
__idForHelp__ = """"""
__executionGranularity__ = """full"""
#DeclarationsEnd
### Begin Automatic Generation Loop ###
loopSize = BS.referenceSize()
loopRange = range(loopSize)
for loopIterator in loopRange:
	datasetIterator = loopIterator
	bs = BS.value(loopIterator)
	cali = CALI.value(loopIterator)
	rhob = RHOB.value(loopIterator)
	drho = DRHO.value(loopIterator)
	flag = MissingValue
	nphi = NPHI.value(loopIterator)
	pef = PEF.value(loopIterator)
	dcal = MissingValue
	nphi_clean = MissingValue
	pef_clean = MissingValue
	rhob_clean = MissingValue
	badhole = MissingValue
	ress = RESS.value(loopIterator)
	resd = RESD.value(loopIterator)
	ecgr = ECGR_REF.value(loopIterator)
	ecgr_clean = MissingValue
	resd_clean = MissingValue
	ress_clean = MissingValue
	### Automatic Generation Loop End ###
	dcal=cali-bs
	if dcal>3 or drho>0.15 or rhob<2.2 or cali>20:
		badhole =1
		if dcal>3: 
			flag=1
			
		if drho>0.15:
			flag=2
		
		if drho>0.15 and dcal>3:
			flag=3
		
		if rhob<2.2:
			flag=4
		
		if cali>20:
			flag=5
			
		nphi_clean=-9999
		pef_clean=-9999
		rhob_clean=-9999
		ecgr_clean=-9999
		resd_clean=-9999
		ress_clean=-9999
	else:
		badhole=0
		flag=0
		nphi_clean=nphi
		pef_clean=pef
		rhob_clean=rhob
		ecgr_clean=ecgr
		resd_clean=resd
		ress_clean=ress
	
	### Begin Automatic Generation EndLoop ###
	FLAG.setValue(loopIterator, flag)
	DCAL.setValue(loopIterator, dcal)
	NPHI_CLEAN.setValue(loopIterator, nphi_clean)
	PEF_CLEAN.setValue(loopIterator, pef_clean)
	RHOB_CLEAN.setValue(loopIterator, rhob_clean)
	BADHOLE.setValue(loopIterator, badhole)
	ECGR_CLEAN.setValue(loopIterator, ecgr_clean)
	RESD_CLEAN.setValue(loopIterator, resd_clean)
	RESS_CLEAN.setValue(loopIterator, ress_clean)
FLAG.save(True)
DCAL.save(True)
NPHI_CLEAN.save(True)
PEF_CLEAN.save(True)
RHOB_CLEAN.save(True)
BADHOLE.save(True)
ECGR_CLEAN.save(True)
RESD_CLEAN.save(True)
RESS_CLEAN.save(True)
### Automatic Generation EndLoop End ###
